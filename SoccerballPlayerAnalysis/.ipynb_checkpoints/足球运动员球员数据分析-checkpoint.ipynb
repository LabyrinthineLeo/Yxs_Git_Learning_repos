# %% [markdown]
# ### 足球运动员球员数据分析
# * 足球运动员是否受出生日期的影响？
# * 左撇子适合踢足球吗？
# * 足球运动员的号码是否与位置相关？
# * 足球运动员的年龄与能力具有怎样的关联？
# * 哪些技能会对足球运动员的综合能力造成较大的影响？

# %% [markdown]
# #### 1、程序实现
# ##### 1.1、导入相关库

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
import seaborn as sns

sns.set(style="darkgrid",font="SimHei", font_scale=1.5, rc={"axes.unicode_minus": False})
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### 1.2、加载相关数据集

# %%
# 读取参数指定的文件，返回一个DataFrame类型的对象。
data = pd.read_csv("./archive/FIFA_Player_2019.csv")
print(data.shape)
data.head(3)
data.sample()
# Out:
# (18207, 89)
#        Unnamed: 0      ID      Name  Age  \
# 14005       14005  227603  P. Kpozo   20
#
#                                                 Photo Nationality  \
# 14005  https://cdn.sofifa.org/players/4/19/227603.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 14005  https://cdn.sofifa.org/flags/117.png       61         68
#
#                 Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 14005  Östersunds FK  ...      53.0    50.0           60.0           57.0
#
#       GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 14005      8.0        12.0       14.0           13.0       14.0          €435K
#
# [1 rows x 89 columns]

# %%
# 数据集中的列，并非都是我们分析所需要的，我们可以有选择性的进行加载，只加载我们需要的信息列（特征列）。
columns = ["Name", "Age", "Nationality", "Overall", "Potential", "Club", "Value", "Wage", "Preferred Foot",
          "Position", "Jersey Number", "Joined", "Height", "Weight", "Crossing", "Finishing",
          "HeadingAccuracy", "ShortPassing", "Volleys", "Dribbling", "Curve", "FKAccuracy", "LongPassing",
          "BallControl", "Acceleration", "SprintSpeed", "Agility", "Reactions", "Balance", "ShotPower", 
          "Jumping", "Stamina", "Strength", "LongShots", "Aggression", "Interceptions", "Positioning", "Vision",
          "Penalties", "Composure", "Marking", "StandingTackle", "SlidingTackle", "GKDiving", "GKHandling",
          "GKKicking", "GKPositioning", "GKReflexes", "Release Clause"]
# 参数指定所要读取的列。
data = pd.read_csv("./archive/FIFA_Player_2019.csv", usecols=columns)
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot Position  ...  \
# 0         FC Barcelona  €110.5M  €565K           Left       RF  ...
# 1             Juventus     €77M  €405K          Right       ST  ...
# 2  Paris Saint-Germain  €118.5M  €290K          Right       LW  ...
# 3    Manchester United     €72M  €260K          Right       GK  ...
# 4      Manchester City    €102M  €355K          Right      RCM  ...
#
#    Composure Marking StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0       96.0    33.0           28.0          26.0       6.0        11.0
# 1       95.0    28.0           31.0          23.0       7.0        11.0
# 2       94.0    27.0           24.0          33.0       9.0         9.0
# 3       68.0    15.0           21.0          13.0      90.0        85.0
# 4       88.0    68.0           58.0          51.0      15.0        13.0
#
#    GKKicking  GKPositioning  GKReflexes  Release Clause
# 0       15.0           14.0         8.0         €226.5M
# 1       15.0           14.0        11.0         €127.1M
# 2       15.0           15.0        11.0         €228.1M
# 3       87.0           88.0        94.0         €138.6M
# 4        5.0           10.0        13.0         €196.4M
#
# [5 rows x 49 columns]

# %%
# 设置显示的最大列数。
pd.set_option("max_columns", 100)
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot Position  Jersey Number  \
# 0         FC Barcelona  €110.5M  €565K           Left       RF           10.0
# 1             Juventus     €77M  €405K          Right       ST            7.0
# 2  Paris Saint-Germain  €118.5M  €290K          Right       LW           10.0
# 3    Manchester United     €72M  €260K          Right       GK            1.0
# 4      Manchester City    €102M  €355K          Right      RCM            7.0
#
#          Joined Height  Weight  Crossing  Finishing  HeadingAccuracy  \
# 0   Jul 1, 2004    5'7  159lbs      84.0       95.0             70.0
# 1  Jul 10, 2018    6'2  183lbs      84.0       94.0             89.0
# 2   Aug 3, 2017    5'9  150lbs      79.0       87.0             62.0
# 3   Jul 1, 2011    6'4  168lbs      17.0       13.0             21.0
# 4  Aug 30, 2015   5'11  154lbs      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 0          90.0     86.0       97.0   93.0        94.0         87.0
# 1          81.0     87.0       88.0   81.0        76.0         77.0
# 2          84.0     84.0       96.0   88.0        87.0         78.0
# 3          50.0     13.0       18.0   21.0        19.0         51.0
# 4          92.0     82.0       86.0   85.0        83.0         91.0
#
#    BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 0         96.0          91.0         86.0     91.0       95.0     95.0
# 1         94.0          89.0         91.0     87.0       96.0     70.0
# 2         95.0          94.0         90.0     96.0       94.0     84.0
# 3         42.0          57.0         58.0     60.0       90.0     43.0
# 4         91.0          78.0         76.0     79.0       91.0     77.0
#
#    ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0       85.0     68.0     72.0      59.0       94.0        48.0
# 1       95.0     95.0     88.0      79.0       93.0        63.0
# 2       80.0     61.0     81.0      49.0       82.0        56.0
# 3       31.0     67.0     43.0      64.0       12.0        38.0
# 4       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes Release Clause
# 0           14.0         8.0        €226.5M
# 1           14.0        11.0        €127.1M
# 2           15.0        11.0        €228.1M
# 3           88.0        94.0        €138.6M
# 4           10.0        13.0        €196.4M

# %% [markdown]
# #### 2、数据清洗
# ##### 2.1、缺失值处理
# * 通过info查看数据信息
# * 通过innull和sum结合，查看缺失值情况

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 49 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             18207 non-null  object
#  1   Age              18207 non-null  int64
#  2   Nationality      18207 non-null  object
#  3   Overall          18207 non-null  int64
#  4   Potential        18207 non-null  int64
#  5   Club             17966 non-null  object
#  6   Value            18207 non-null  object
#  7   Wage             18207 non-null  object
#  8   Preferred Foot   18159 non-null  object
#  9   Position         18147 non-null  object
#  10  Jersey Number    18147 non-null  float64
#  11  Joined           16654 non-null  object
#  12  Height           18159 non-null  object
#  13  Weight           18159 non-null  object
#  14  Crossing         18159 non-null  float64
#  15  Finishing        18159 non-null  float64
#  16  HeadingAccuracy  18159 non-null  float64
#  17  ShortPassing     18159 non-null  float64
#  18  Volleys          18159 non-null  float64
#  19  Dribbling        18159 non-null  float64
#  20  Curve            18159 non-null  float64
#  21  FKAccuracy       18159 non-null  float64
#  22  LongPassing      18159 non-null  float64
#  23  BallControl      18159 non-null  float64
#  24  Acceleration     18159 non-null  float64
#  25  SprintSpeed      18159 non-null  float64
#  26  Agility          18159 non-null  float64
#  27  Reactions        18159 non-null  float64
#  28  Balance          18159 non-null  float64
#  29  ShotPower        18159 non-null  float64
#  30  Jumping          18159 non-null  float64
#  31  Stamina          18159 non-null  float64
#  32  Strength         18159 non-null  float64
#  33  LongShots        18159 non-null  float64
#  34  Aggression       18159 non-null  float64
#  35  Interceptions    18159 non-null  float64
#  36  Positioning      18159 non-null  float64
#  37  Vision           18159 non-null  float64
#  38  Penalties        18159 non-null  float64
#  39  Composure        18159 non-null  float64
#  40  Marking          18159 non-null  float64
#  41  StandingTackle   18159 non-null  float64
#  42  SlidingTackle    18159 non-null  float64
#  43  GKDiving         18159 non-null  float64
#  44  GKHandling       18159 non-null  float64
#  45  GKKicking        18159 non-null  float64
#  46  GKPositioning    18159 non-null  float64
#  47  GKReflexes       18159 non-null  float64
#  48  Release Clause   16643 non-null  object
# dtypes: float64(35), int64(3), object(11)
# memory usage: 6.8+ MB

# %%
data.isnull().sum(axis=0)
# Out:
# Name                  0
# Age                   0
# Nationality           0
# Overall               0
# Potential             0
# Club                241
# Value                 0
# Wage                  0
# Preferred Foot       48
# Position             60
# Jersey Number        60
# Joined             1553
# Height               48
# Weight               48
# Crossing             48
# Finishing            48
# HeadingAccuracy      48
# ShortPassing         48
# Volleys              48
# Dribbling            48
# Curve                48
# FKAccuracy           48
# LongPassing          48
# BallControl          48
# Acceleration         48
# SprintSpeed          48
# Agility              48
# Reactions            48
# Balance              48
# ShotPower            48
# Jumping              48
# Stamina              48
# Strength             48
# LongShots            48
# Aggression           48
# Interceptions        48
# Positioning          48
# Vision               48
# Penalties            48
# Composure            48
# Marking              48
# StandingTackle       48
# SlidingTackle        48
# GKDiving             48
# GKHandling           48
# GKKicking            48
# GKPositioning        48
# GKReflexes           48
# Release Clause     1564
# dtype: int64

# %%
# 删除所有含有空值的行。修改原始数据。
data.dropna(axis=0, inplace=True)
data.isnull().sum()
# Out:
# Name               0
# Age                0
# Nationality        0
# Overall            0
# Potential          0
# Club               0
# Value              0
# Wage               0
# Preferred Foot     0
# Position           0
# Jersey Number      0
# Joined             0
# Height             0
# Weight             0
# Crossing           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# Release Clause     0
# dtype: int64

# %% [markdown]
# ##### 2.2、异常值处理
# * 通过describe查看数值信息
# * 可配合箱线图辅助
# * 异常值可以删除，视为缺失值或者不处理

# %%
data.describe()
sns.boxplot(data=data[["Age", "Overall"]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 2.3、重复值处理
# * 使用duplicate检查重复项，可配合keep参数进行调整
# * 使用drop_duplicate删除重复项

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 3、数据分析
# ##### 3.1、数据转换
# * 我们要统计身高与体重的分布情况，不过，身高与体重目前并不是数值类型，我们需要进行转换后，才能进行统计计算。这里，我们将身高与体重转换成熟悉的单位。
# * 1英尺 = 30.48厘米
# * 1英寸 = 2.54厘米
# * 1磅 = 0.45千克

# %%
def tran_height(height):
    v = height.split("'")
    return int(v[0]) * 30.48 + int(v[1]) * 2.54

def tran_weight(weight):
    v = int(weight.replace("lbs", ""))
    return v * 0.45

data["Height"] = data["Height"].apply(tran_height)
data["Weight"] = data["Weight"].apply(tran_weight)

# %%
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot Position  Jersey Number  \
# 0         FC Barcelona  €110.5M  €565K           Left       RF           10.0
# 1             Juventus     €77M  €405K          Right       ST            7.0
# 2  Paris Saint-Germain  €118.5M  €290K          Right       LW           10.0
# 3    Manchester United     €72M  €260K          Right       GK            1.0
# 4      Manchester City    €102M  €355K          Right      RCM            7.0
#
#          Joined  Height  Weight  Crossing  Finishing  HeadingAccuracy  \
# 0   Jul 1, 2004  170.18   71.55      84.0       95.0             70.0
# 1  Jul 10, 2018  187.96   82.35      84.0       94.0             89.0
# 2   Aug 3, 2017  175.26   67.50      79.0       87.0             62.0
# 3   Jul 1, 2011  193.04   75.60      17.0       13.0             21.0
# 4  Aug 30, 2015  180.34   69.30      93.0       82.0             55.0
#
#    ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# 0          90.0     86.0       97.0   93.0        94.0         87.0
# 1          81.0     87.0       88.0   81.0        76.0         77.0
# 2          84.0     84.0       96.0   88.0        87.0         78.0
# 3          50.0     13.0       18.0   21.0        19.0         51.0
# 4          92.0     82.0       86.0   85.0        83.0         91.0
#
#    BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  \
# 0         96.0          91.0         86.0     91.0       95.0     95.0
# 1         94.0          89.0         91.0     87.0       96.0     70.0
# 2         95.0          94.0         90.0     96.0       94.0     84.0
# 3         42.0          57.0         58.0     60.0       90.0     43.0
# 4         91.0          78.0         76.0     79.0       91.0     77.0
#
#    ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0       85.0     68.0     72.0      59.0       94.0        48.0
# 1       95.0     95.0     88.0      79.0       93.0        63.0
# 2       80.0     61.0     81.0      49.0       82.0        56.0
# 3       31.0     67.0     43.0      64.0       12.0        38.0
# 4       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes Release Clause
# 0           14.0         8.0        €226.5M
# 1           14.0        11.0        €127.1M
# 2           15.0        11.0        €228.1M
# 3           88.0        94.0        €138.6M
# 4           10.0        13.0        €196.4M

# %% [markdown]
# ##### 3.2、绘制核密度图
# 数据转换后，可以检测身高和体重的分布

# %%
fig, ax = plt.subplots(1, 2)
fig.set_size_inches((18, 5))
sns.distplot(data[["Height"]], bins=50, ax=ax[0], color="g")
sns.distplot(data["Weight"], bins=50, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %% [markdown]
# #### 4、特征项分析

# %% [markdown]
# ##### 4.1、左右脚习惯对球员的能力影响

# %%
# 数量上对比
number = data["Preferred Foot"].value_counts()
print(number)
sns.countplot(x="Preferred Foot", data=data)
# Out:
# Right    12823
# Left      3820
# Name: Preferred Foot, dtype: int64
# <AxesSubplot:xlabel='Preferred Foot', ylabel='count'>

# %%
# 能力上对比
print(data.groupby("Preferred Foot")["Overall"].mean())
sns.barplot(x="Preferred Foot", y="Overall", data=data)
# Out:
# Preferred Foot
# Left     66.740838
# Right    65.990564
# Name: Overall, dtype: float64
# <AxesSubplot:xlabel='Preferred Foot', ylabel='Overall'>

# %% [markdown]
# * 位置上对比
#
# 由于在综合能力上体现不明显，我们现在通过每个位置，进行更细致的分析。为了分析的客观性，我们只统计左脚与右脚都超过50人（含50人）的位置。
# 首先，我们来计算哪些位置左右脚球员都达到了50人。

# %%
t = data.groupby(["Preferred Foot", "Position"]).size()
t = t.unstack()
t[t < 50] = np.NaN
t.dropna(axis=1, inplace=True)
display(t)
# Out:
# Position        CAM    CB  CDM    CM    GK    LB  LCB  LCM   LM   LW   RM  \
# Preferred Foot
# Left            232   313  117   226   193  1071  244   86  372   98  220
# Right           645  1333  756  1050  1707   152  351  267  640  240  802
#
# Position         RW    ST
# Preferred Foot
# Left             79   256
# Right           246  1668

# %%
t2 = data[data["Position"].isin(t.columns)]
plt.figure(figsize=(18, 10))
sns.barplot(x="Position", y="Overall", hue="Preferred Foot", hue_order=["Left", "Right"], data=t2)
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Overall'>

# %% [markdown]
# * 可从结果得知，左脚选手更适合RW左边锋位置

# %% [markdown]
# ##### 4.2、隶属俱乐部/国家队对球员能力的影响

# %%
# 俱乐部
g = data.groupby("Club")
r = g["Overall"].agg(["mean", "count"])
r = r[r["count"] >= 20]
r = r.sort_values("mean", ascending=False).head(10)
display(r)
r.plot(kind="bar")
# Out:
#                           mean  count
# Club
# Juventus             82.280000     25
# Napoli               80.041667     24
# Inter                79.619048     21
# Real Madrid          78.242424     33
# FC Barcelona         78.030303     33
# Milan                77.541667     24
# Paris Saint-Germain  77.433333     30
# Roma                 77.400000     25
# Manchester United    77.242424     33
# SL Benfica           77.074074     27
# <AxesSubplot:xlabel='Club'>

# %%
# 国家队
g = data.groupby("Nationality")
r = g["Overall"].agg(["mean", "count"])
r = r[r["count"] >= 50]
r = r.sort_values("mean", ascending=False).head(10)
display(r)
r.plot(kind="bar")
# Out:
#                      mean  count
# Nationality
# Portugal        71.406897    290
# Brazil          71.251269    788
# Uruguay         70.443609    133
# Algeria         70.392857     56
# Ukraine         70.347222     72
# Spain           69.733060    974
# Morocco         69.721519     79
# Serbia          69.612069    116
# Czech Republic  69.548387     93
# Croatia         69.407080    113
# <AxesSubplot:xlabel='Nationality'>

# %% [markdown]
# ##### 4.3、服役时间长短对球员能力的影响

# %%
t = pd.to_datetime(data["Joined"])
t = t.astype(np.str)
join_year = t.apply(lambda item: int(item.split("-")[0]))
over_five_year = (2018 - join_year) >= 5
t2 = data[over_five_year]
t2 = t2["Club"].value_counts()
# display(t2)
t2.iloc[:15].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 4.4、出生日期与球员能力相关性

# %%
data2 = pd.read_csv("./archive/FIFA_WC2018_Player.csv")
data2.head()
# Out:
#         Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1  Argentina  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2  Argentina  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3  Argentina  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4  Argentina  10   FW        MESSI Lionel  24.06.1987       MESSI
#
#                        Club  Height  Weight
# 0            AFC Ajax (NED)     169      65
# 1     CA Boca Juniors (ARG)     169      65
# 2  West Ham United FC (ENG)     167      66
# 3          SL Benfica (POR)     167      69
# 4        FC Barcelona (ESP)     170      72

# %%
t = data2["Birth Date"].str.split(".", expand=True)
# t
# t[0].value_counts().plot(kind="bar")
# t[1].value_counts().plot(kind="bar")
# t[2].value_counts().plot(kind="bar")
t[2].value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 4.5、运动员号码与球员位置相关性

# %%
g = data.groupby(["Jersey Number", "Position"])
t = g.size()
# display(t)
t = t[t >= 100]
t.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Jersey Number,Position'>

# %% [markdown]
# ##### 4.6、球员身价的相关因素分析（薪水、违约金等）

# %%
def to_numeric(item):
    item = item.replace("€", "")
    value = float(item[:-1])
    if item[-1] == "M":
        value *= 1000
    return value

data["Value"] = data["Value"].apply(to_numeric)
data["Wage"] = data["Wage"].apply(to_numeric)
data["Release Clause"] = data["Release Clause"].apply(to_numeric)
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot Position  \
# 0         FC Barcelona  110500.0  565.0           Left       RF
# 1             Juventus   77000.0  405.0          Right       ST
# 2  Paris Saint-Germain  118500.0  290.0          Right       LW
# 3    Manchester United   72000.0  260.0          Right       GK
# 4      Manchester City  102000.0  355.0          Right      RCM
#
#    Jersey Number        Joined  Height  Weight  Crossing  Finishing  \
# 0           10.0   Jul 1, 2004  170.18   71.55      84.0       95.0
# 1            7.0  Jul 10, 2018  187.96   82.35      84.0       94.0
# 2           10.0   Aug 3, 2017  175.26   67.50      79.0       87.0
# 3            1.0   Jul 1, 2011  193.04   75.60      17.0       13.0
# 4            7.0  Aug 30, 2015  180.34   69.30      93.0       82.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 0             70.0          90.0     86.0       97.0   93.0        94.0
# 1             89.0          81.0     87.0       88.0   81.0        76.0
# 2             62.0          84.0     84.0       96.0   88.0        87.0
# 3             21.0          50.0     13.0       18.0   21.0        19.0
# 4             55.0          92.0     82.0       86.0   85.0        83.0
#
#    LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# 0         87.0         96.0          91.0         86.0     91.0       95.0
# 1         77.0         94.0          89.0         91.0     87.0       96.0
# 2         78.0         95.0          94.0         90.0     96.0       94.0
# 3         51.0         42.0          57.0         58.0     60.0       90.0
# 4         91.0         91.0          78.0         76.0     79.0       91.0
#
#    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0     95.0       85.0     68.0     72.0      59.0       94.0        48.0
# 1     70.0       95.0     95.0     88.0      79.0       93.0        63.0
# 2     84.0       80.0     61.0     81.0      49.0       82.0        56.0
# 3     43.0       31.0     67.0     43.0      64.0       12.0        38.0
# 4     77.0       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes  Release Clause
# 0           14.0         8.0        226500.0
# 1           14.0        11.0        127100.0
# 2           15.0        11.0        228100.0
# 3           88.0        94.0        138600.0
# 4           10.0        13.0        196400.0

# %%
sns.scatterplot(x="Value", y="Height", data=data)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Height'>

# %% [markdown]
# ##### 4.7、球员综合能力影响因子探索

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(data.corr(), annot=True, fmt=".2f", cmap=plt.cm.Greens)
plt.savefig("corr.png", dpi=100, bbox_inches="tight")

# %%
# 年龄关系
sns.scatterplot(x="Age", y="Overall", data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Overall'>

# %%
data["Age"].corr(data["Overall"])
# Out:
# 0.46497701392741886

# %%
# 对一个数组进行切分，可以将连续值变成离散值。
# bins 指定区间数量（桶数）。bins如果为int类型，则进行等分。
# 此处的区间边界与为前开后闭。
# pd.cut(t["Age"], bins=4)
# 如果需要进行区间的不等分，则可以将bins参数指定为数组类型。
# 数组来指定区间的边界。
def get_acc(item):
    return 1-item
min_, max_ = data["Age"].min() - 0.5, data["Age"].max()
# pd.cut(t["Age"], bins=[min_, 20, 30, 40, max_])
# pd.cut 默认显示的内容为区间的范围，如果我们希望自定义内容(每个区间显示的内容)，可以通过labels参数
# 进行指定。
t = pd.cut(data["Age"], bins=[min_, 20, 30, 40, max_], labels=["20", "30","40", "50"])

t = pd.concat((t, data["Overall"]), axis=1)
# display(t)
g = t.groupby("Age")
display(g["Overall"].mean())
sns.lineplot(y="Overall", marker="*", ms=30, x="Age", data=t)
# Out:
# Age
# 20    59.679723
# 30    67.375275
# 40    69.375779
# 50    63.888889
# Name: Overall, dtype: float64
# <AxesSubplot:xlabel='Age', ylabel='Overall'>

# %% [markdown]
# #### 5、Adaboost建模分析
# ##### 5.1、数据清洗

# %%
# 去除影响因子小的特征项
columns = ["Overall", "Age","Preferred Foot",
          "Potential", "Crossing", "Finishing",
          "HeadingAccuracy", "ShortPassing", "Volleys", "Dribbling", "Curve", "FKAccuracy", "LongPassing",
          "BallControl", "Acceleration", "SprintSpeed", "Agility", "Reactions", "Balance", "ShotPower", 
          "Jumping", "Stamina", "Strength", "LongShots", "Aggression", "Interceptions", "Positioning", "Vision",
          "Penalties", "Composure", "Marking", "StandingTackle", "SlidingTackle", "GKDiving", "GKHandling",
          "GKKicking", "GKPositioning", "GKReflexes"]
# 参数指定所要读取的列。
data = pd.read_csv("./archive/FIFA_Player_2019.csv", usecols=columns)
# 左右脚偏好
def to_ind(item):
    if item == 'Left':
        value = 0
    else:
        value = 1
    return value

data["Preferred Foot"] = data["Preferred Foot"].apply(to_ind)

oa = data['Overall']
data = data.drop('Overall', axis=1)
data.insert(0, 'Overall', oa)
# 删除所有含有空值的行。修改原始数据。
data.dropna(axis=0, inplace=True)
data.head()
# Out:
#    Overall  Age  Potential  Preferred Foot  Crossing  Finishing  \
# 0       94   31         94               0      84.0       95.0
# 1       94   33         94               1      84.0       94.0
# 2       92   26         93               1      79.0       87.0
# 3       91   27         93               1      17.0       13.0
# 4       91   27         92               1      93.0       82.0
#
#    HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  FKAccuracy  \
# 0             70.0          90.0     86.0       97.0   93.0        94.0
# 1             89.0          81.0     87.0       88.0   81.0        76.0
# 2             62.0          84.0     84.0       96.0   88.0        87.0
# 3             21.0          50.0     13.0       18.0   21.0        19.0
# 4             55.0          92.0     82.0       86.0   85.0        83.0
#
#    LongPassing  BallControl  Acceleration  SprintSpeed  Agility  Reactions  \
# 0         87.0         96.0          91.0         86.0     91.0       95.0
# 1         77.0         94.0          89.0         91.0     87.0       96.0
# 2         78.0         95.0          94.0         90.0     96.0       94.0
# 3         51.0         42.0          57.0         58.0     60.0       90.0
# 4         91.0         91.0          78.0         76.0     79.0       91.0
#
#    Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  \
# 0     95.0       85.0     68.0     72.0      59.0       94.0        48.0
# 1     70.0       95.0     95.0     88.0      79.0       93.0        63.0
# 2     84.0       80.0     61.0     81.0      49.0       82.0        56.0
# 3     43.0       31.0     67.0     43.0      64.0       12.0        38.0
# 4     77.0       91.0     63.0     90.0      75.0       91.0        76.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0           22.0         94.0    94.0       75.0       96.0     33.0
# 1           29.0         95.0    82.0       85.0       95.0     28.0
# 2           36.0         89.0    87.0       81.0       94.0     27.0
# 3           30.0         12.0    68.0       40.0       68.0     15.0
# 4           61.0         87.0    94.0       79.0       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0

# %%
y = data.iloc[:,0].values
x = data.iloc[:,1:].values

# %% [markdown]
# ##### 5.2、数据预处理

# %%
from sklearn.model_selection import train_test_split
# 分割数据集
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[-0.02842744,  0.11313914,  0.54587609, ..., -0.07357928,
#         -0.49197178, -0.31657889],
#        [-0.67234445,  0.93271244,  0.54587609, ..., -0.49960008,
#         -0.55095691, -0.48418287],
#        [ 0.83012857, -0.87034882,  0.54587609, ..., -0.25615962,
#         -0.3150164 , -0.37244688],
#        ...,
#        [ 0.18621156, -0.5425195 ,  0.54587609, ..., -0.13443939,
#         -0.60994204, -0.31657889],
#        [-0.45770545,  0.76879778, -1.83191759, ..., -0.43873996,
#         -0.43298666, -0.42831488],
#        [-0.45770545,  0.2770538 , -1.83191759, ..., -0.56046019,
#         -0.43298666, -0.03723892]])

# %% [markdown]
# ##### 5.3、模型选择——Adaboost

# %%
# 训练模型
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.font_manager import FontProperties
from sklearn.ensemble import AdaBoostClassifier

# 训练模型：10个评估器，学习率为0.1
classifier = AdaBoostClassifier(n_estimators = 10,learning_rate = 0.1)
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)

# %% [markdown]
# ##### 5.4、评价指标

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
# 预测模型
accuracy = get_acc(accuracy_score(y_test, y_pred))
# 查看准确率
print("accuracy:",accuracy)
# Out:
# accuracy: 0.888215859030837
